# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sol = np.load('./sol.npy')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.plot(sol[:, 0], sol[:, 3])
ax.set_xlabel(r'$\theta_1$')
ax.set_ylabel(r'$\dot{\theta}_1$')
plt.title('Trajectory under learned controller')
plt.show()
